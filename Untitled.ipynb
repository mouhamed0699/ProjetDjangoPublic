# %%
import json

# %%
with open("data.json") as fichier_json:
    data=json.load(fichier_json)

# %%
data
# Out:
# [{'type': 'flight-offer',
#   'id': '1',
#   'source': 'GDS',
#   'instantTicketingRequired': False,
#   'nonHomogeneous': False,
#   'oneWay': False,
#   'lastTicketingDate': '2023-05-23',
#   'lastTicketingDateTime': '2023-05-23',
#   'numberOfBookableSeats': 9,
#   'itineraries': [{'duration': 'PT16H5M',
#     'segments': [{'departure': {'iataCode': 'SYD',
#        'terminal': '1',
#        'at': '2023-06-01T20:45:00'},
#       'arrival': {'iataCode': 'SIN',
#        'terminal': '1',
#        'at': '2023-06-02T03:10:00'},
#       'carrierCode': 'TR',
#       'number': '13',
#       'aircraft': {'code': '788'},
#       'operating': {'carrierCode': 'TR'},
#       'duration': 'PT8H25M',
#       'id': '19',
#       'numberOfStops': 0,
#       'blacklistedInEU': False},
#      {'departure': {'iataCode': 'SIN',
#        'terminal': '1',
#        'at': '2023-06-02T08:20:00'},
#       'arrival': {'iataCode': 'BKK', 'at': '2023-06-02T09:50:00'},
#       'carrierCode': 'TR',
# ...

# %%
list=data[0]
list
# Out:
# {'type': 'flight-offer',
#  'id': '1',
#  'source': 'GDS',
#  'instantTicketingRequired': False,
#  'nonHomogeneous': False,
#  'oneWay': False,
#  'lastTicketingDate': '2023-05-23',
#  'lastTicketingDateTime': '2023-05-23',
#  'numberOfBookableSeats': 9,
#  'itineraries': [{'duration': 'PT16H5M',
#    'segments': [{'departure': {'iataCode': 'SYD',
#       'terminal': '1',
#       'at': '2023-06-01T20:45:00'},
#      'arrival': {'iataCode': 'SIN',
#       'terminal': '1',
#       'at': '2023-06-02T03:10:00'},
#      'carrierCode': 'TR',
#      'number': '13',
#      'aircraft': {'code': '788'},
#      'operating': {'carrierCode': 'TR'},
#      'duration': 'PT8H25M',
#      'id': '19',
#      'numberOfStops': 0,
#      'blacklistedInEU': False},
#     {'departure': {'iataCode': 'SIN',
#       'terminal': '1',
#       'at': '2023-06-02T08:20:00'},
#      'arrival': {'iataCode': 'BKK', 'at': '2023-06-02T09:50:00'},
#      'carrierCode': 'TR',
#      'number': '624',
# ...

# %%
list['itineraries']
# Out:
# [{'duration': 'PT16H5M',
#   'segments': [{'departure': {'iataCode': 'SYD',
#      'terminal': '1',
#      'at': '2023-06-01T20:45:00'},
#     'arrival': {'iataCode': 'SIN',
#      'terminal': '1',
#      'at': '2023-06-02T03:10:00'},
#     'carrierCode': 'TR',
#     'number': '13',
#     'aircraft': {'code': '788'},
#     'operating': {'carrierCode': 'TR'},
#     'duration': 'PT8H25M',
#     'id': '19',
#     'numberOfStops': 0,
#     'blacklistedInEU': False},
#    {'departure': {'iataCode': 'SIN',
#      'terminal': '1',
#      'at': '2023-06-02T08:20:00'},
#     'arrival': {'iataCode': 'BKK', 'at': '2023-06-02T09:50:00'},
#     'carrierCode': 'TR',
#     'number': '624',
#     'aircraft': {'code': '32Q'},
#     'operating': {'carrierCode': 'TR'},
#     'duration': 'PT2H30M',
#     'id': '20',
#     'numberOfStops': 0,
#     'blacklistedInEU': False}]}]

# %%
list['itineraries'][0]
# Out:
# {'duration': 'PT16H5M',
#  'segments': [{'departure': {'iataCode': 'SYD',
#     'terminal': '1',
#     'at': '2023-06-01T20:45:00'},
#    'arrival': {'iataCode': 'SIN',
#     'terminal': '1',
#     'at': '2023-06-02T03:10:00'},
#    'carrierCode': 'TR',
#    'number': '13',
#    'aircraft': {'code': '788'},
#    'operating': {'carrierCode': 'TR'},
#    'duration': 'PT8H25M',
#    'id': '19',
#    'numberOfStops': 0,
#    'blacklistedInEU': False},
#   {'departure': {'iataCode': 'SIN',
#     'terminal': '1',
#     'at': '2023-06-02T08:20:00'},
#    'arrival': {'iataCode': 'BKK', 'at': '2023-06-02T09:50:00'},
#    'carrierCode': 'TR',
#    'number': '624',
#    'aircraft': {'code': '32Q'},
#    'operating': {'carrierCode': 'TR'},
#    'duration': 'PT2H30M',
#    'id': '20',
#    'numberOfStops': 0,
#    'blacklistedInEU': False}]}

# %%
list['itineraries'][0]['segments']
# Out:
# [{'departure': {'iataCode': 'SYD',
#    'terminal': '1',
#    'at': '2023-06-01T20:45:00'},
#   'arrival': {'iataCode': 'SIN', 'terminal': '1', 'at': '2023-06-02T03:10:00'},
#   'carrierCode': 'TR',
#   'number': '13',
#   'aircraft': {'code': '788'},
#   'operating': {'carrierCode': 'TR'},
#   'duration': 'PT8H25M',
#   'id': '19',
#   'numberOfStops': 0,
#   'blacklistedInEU': False},
#  {'departure': {'iataCode': 'SIN',
#    'terminal': '1',
#    'at': '2023-06-02T08:20:00'},
#   'arrival': {'iataCode': 'BKK', 'at': '2023-06-02T09:50:00'},
#   'carrierCode': 'TR',
#   'number': '624',
#   'aircraft': {'code': '32Q'},
#   'operating': {'carrierCode': 'TR'},
#   'duration': 'PT2H30M',
#   'id': '20',
#   'numberOfStops': 0,
#   'blacklistedInEU': False}]

# %%
list['itineraries'][0]['segments'][0]
# Out:
# {'departure': {'iataCode': 'SYD',
#   'terminal': '1',
#   'at': '2023-06-01T20:45:00'},
#  'arrival': {'iataCode': 'SIN', 'terminal': '1', 'at': '2023-06-02T03:10:00'},
#  'carrierCode': 'TR',
#  'number': '13',
#  'aircraft': {'code': '788'},
#  'operating': {'carrierCode': 'TR'},
#  'duration': 'PT8H25M',
#  'id': '19',
#  'numberOfStops': 0,
#  'blacklistedInEU': False}

# %%
v
